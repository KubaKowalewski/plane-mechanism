# %%
from src.Slm import slm
import numpy as np
import matplotlib.pyplot as plt
import csv
# Out:
# c:\Users\Kuba\plane-mechanism\src\Slm\slm.py:74: RuntimeWarning: invalid value encountered in arccos
#   def __law_of_cos(self,L1,L2,L3,mode="rad"):
# c:\Users\Kuba\plane-mechanism\src\Slm\slm.py:74: RuntimeWarning: invalid value encountered in arccos
#   def __law_of_cos(self,L1,L2,L3,mode="rad"):
# c:\Users\Kuba\plane-mechanism\src\Slm\slm.py:74: RuntimeWarning: invalid value encountered in arccos
#   def __law_of_cos(self,L1,L2,L3,mode="rad"):
# c:\Users\Kuba\plane-mechanism\src\Slm\slm.py:74: RuntimeWarning: invalid value encountered in arccos
#   def __law_of_cos(self,L1,L2,L3,mode="rad"):
# c:\Users\Kuba\plane-mechanism\src\Slm\slm.py:74: RuntimeWarning: invalid value encountered in arccos
#   def __law_of_cos(self,L1,L2,L3,mode="rad"):
# c:\Users\Kuba\plane-mechanism\src\Slm\slm.py:74: RuntimeWarning: invalid value encountered in arccos
#   def __law_of_cos(self,L1,L2,L3,mode="rad"):
# ...
